# %%
from yolo_dataset import YoloFolderDataset, show_sample
from pathlib import Path
from yolo_step_panel_detector import StepPanelDetector

# %%
dataset_root = Path(r"C:\Users\Kenan\Desktop\IKEA_Project\IKEA_assembly_guide_assistent\dataset")
ds = YoloFolderDataset(
    images_dir=dataset_root / "images",
    labels_dir=dataset_root / "labels",
    classes_path=dataset_root / "classes.txt",  # optional
    return_pil=True,
)

# %%
ds[7]
# Out:
# {'image_path': 'C:\\Users\\Kenan\\Desktop\\IKEA_Project\\IKEA_assembly_guide_assistent\\dataset\\images\\Bench__applaro_2__52f650__page_007.png',
#  'label_path': 'C:\\Users\\Kenan\\Desktop\\IKEA_Project\\IKEA_assembly_guide_assistent\\dataset\\labels\\Bench__applaro_2__52f650__page_007.txt',
#  'width': 1654,
#  'height': 2339,
#  'boxes_xyxy': tensor([[  50.0004,   36.9995, 1623.0007, 2145.9985]]),
#  'class_ids': tensor([0]),
#  'image': <PIL.Image.Image image mode=RGB size=1654x2339>}

# %%
show_sample(ds[7])

# %%
show_sample(ds[26])

# %%
show_sample(ds[119])

# %%
weights = r"C:\Windows\System32\runs\detect\train\weights\best.pt"

detector = StepPanelDetector(weights_path=weights, conf=0.25, iou=0.7, device="cuda:0")

dets = detector.predict_image(r"C:\Users\Kenan\Desktop\IKEA_Project\IKEA_assembly_guide_assistent\images\image_side2.jpg")
print("detections:", len(dets))
if dets:
    print(dets[0])
# Out:
# detections: 2
# Detection(bbox_xyxy=[34.46906280517578, 548.5750122070312, 865.0, 1083.0], conf=0.8772608041763306, cls=0)

# %%
from helpers import visualize_detections

# %%
img_path = r"C:\Users\Kenan\Desktop\IKEA_Project\IKEA_assembly_guide_assistent\images\image_side2.jpg"

# %%
visualize_detections(img_path, dets)

# %%
img2_path = r"C:\Users\Kenan\Desktop\IKEA_Project\IKEA_assembly_guide_assistent\images\test.jpg"

# %%
dets2 = detector.predict_image(img2_path)

# %%
visualize_detections(img2_path, dets2)
